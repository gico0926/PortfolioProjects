# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Read the CSV file
df = pd.read_csv(r'D:\專案\Projects\Youtube channel analysis\Code\gj888ytdata.csv')

# Display the contents of the DataFrame
df

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# channel_name        object
# channel_subs        object
# video_title         object
# publication_date    object
# views               object
# likes                int64
# channel_url         object
# video_url           object
# dtype: object

# %%
df['publication_date']
# Out:
# 0             2024年5月3日
# 1            2024年4月26日
# 2            2024年4月19日
# 3             2024年4月5日
# 4            2024年3月29日
# 5            2024年3月22日
# 6            2024年3月19日
# 7            2024年3月15日
# 8            2024年3月12日
# 9             2024年3月8日
# 10            2024年3月5日
# 11            2024年3月1日
# 12           2024年2月27日
# 13           2024年2月23日
# 14           2024年2月20日
# 15           2024年2月18日
# 16           2024年2月16日
# 17           2024年2月13日
# 18            2024年2月9日
# 19            2024年2月6日
# 20            2024年2月2日
# 21           2024年1月30日
# 22           2024年1月26日
# 23           2024年1月23日
# 24           2024年1月21日
# 25           2024年1月19日
# 26           2024年1月16日
# 27           2024年1月12日
# 28            2024年1月9日
# 29            2024年1月7日
# 30            2024年1月5日
# 31            2024年1月2日
# 32          2023年12月29日
# 33          2023年12月26日
# 34          2023年12月24日
# 35          2023年12月22日
# 36          2023年12月19日
# 37          2023年12月15日
# ...

# %%
df['publication_date'] = df['publication_date'].str.replace('首播日期：','')

# %%
df.to_csv('csv_cleaned.csv', index=False, encoding='utf-8-sig')
